# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-mntgoab_
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-mntgoab_
#   Resolved https://github.com/openai/whisper.git to commit b38a1f20f4b23f3f3099af2c3e0ca95627276ddf
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.1 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230918-py3-none-any.whl size=798405 sha256=223e745eed3a0152468af229bc8e34d64e87b7d5ec421ad40cb7dcdd32a233bc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q1pux25_/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# ...

# %%
# !whisper "input.wav" --model large --language German --word_timestamps True > transcription.txt
# Out:
# 100%|█████████████████████████████████████| 2.87G/2.87G [00:53<00:00, 57.9MiB/s]
